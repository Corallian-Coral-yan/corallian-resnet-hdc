# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
ANNOTATIONS_FILE = r"D:/CROPPED-CORALS/index.csv"
IMG_DIR = r"D:/CROPPED-CORALS/"

num_classes = 34   # 34 classes detected for initial dataset
num_epochs = 20
batch_size = 4
learning_rate = 0.01

model_verbose = True

# %%
from model.resnet_hdc import ResNet18_HDC, ResNet101_HDC

model = ResNet101_HDC(num_classes=num_classes, verbose=model_verbose).to(device)
print(f"Attempting to run ResNet with HDC on device {device}")
print(f"Model architecture: {str(model)}")
# Out:
# Attempting to run ResNet with HDC on device cpu
# Model architecture: ResNet101_HDC(
#   (layer_1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer_2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer_3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer_4): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (layer_5): ResidualHDCBlock_O(
#     (res_1x1): Sequential(
#       (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_6): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_7): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_8): ResidualHDCBlock_O(
#     (downsample): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(2, 2))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (res_1x1): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_9): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_10): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_11): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_12): ResidualHDCBlock_O(
#     (downsample): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(2, 2))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (res_1x1): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2), dilation=(2, 2))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_13): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_14): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_15): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(9, 9), dilation=(9, 9))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_16): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_17): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_18): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_19): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(9, 9), dilation=(9, 9))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_20): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_21): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_22): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_23): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(9, 9), dilation=(9, 9))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_24): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_25): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_26): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_27): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(9, 9), dilation=(9, 9))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_28): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_29): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_30): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_31): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(9, 9), dilation=(9, 9))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_32): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_33): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_34): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(5, 5), dilation=(5, 5))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_35): ResidualHDCBlock_O(
#     (downsample): Sequential(
#       (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(2, 2))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (res_1x1): Sequential(
#       (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(5, 5), dilation=(5, 5))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_36): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(9, 9), dilation=(9, 9))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_37): ResidualHDCBlock_X(
#     (conv_1x1_reduce): Sequential(
#       (0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_3x3): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(17, 17), dilation=(17, 17))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv_1x1_increase): Sequential(
#       (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (layer_38): AvgPool2d(kernel_size=16, stride=1, padding=0)
#   (fc): Linear(in_features=2048, out_features=34, bias=True)
# )

# %%
from dataset.image_dataset import ImageDataset

def data_loader(batch_size, random_seed=42, valid_size=0.1, shuffle=True, test=False):
    # define transforms
    transform = transforms.ToTensor()
    target_transform = None

    if test:
        dataset = ImageDataset(
            ANNOTATIONS_FILE, 
            IMG_DIR, 
            transform=transform, 
            target_transform=target_transform, 
            random_state=random_seed
        )

        data_loader = torch.utils.data.DataLoader(
            dataset, batch_size=batch_size, shuffle=shuffle
        )

        return data_loader

    # load the dataset
    train_dataset = ImageDataset(ANNOTATIONS_FILE, IMG_DIR, train=True, transform=transform, target_transform=target_transform, random_state=random_seed)
    valid_dataset = ImageDataset(ANNOTATIONS_FILE, IMG_DIR, train=True, transform=transform, target_transform=target_transform, random_state=random_seed)

    num_train = 64
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler)

    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler)

    return (train_loader, valid_loader)

# %%
train_loader, valid_loader = data_loader(batch_size=batch_size)
test_loader = data_loader(batch_size=batch_size, test=True)
# Out:
# 0       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 2       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 3       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 4       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
#                               ...
# 1795    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1796    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1797    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1798    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1799    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# Name: filepath, Length: 1698, dtype: object
# Annotations File: D:/CROPPED-CORALS/index.csv
# Image Base Directory: D:/CROPPED-CORALS/
# Train=True, Transform=ToTensor(), Target Transform=None, Random State=42
# 0       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 2       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 3       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 4       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
#                               ...
# 1795    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1796    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1797    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1798    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1799    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# Name: filepath, Length: 1698, dtype: object
# Annotations File: D:/CROPPED-CORALS/index.csv
# Image Base Directory: D:/CROPPED-CORALS/
# Train=True, Transform=ToTensor(), Target Transform=None, Random State=42
# 0       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 2       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 3       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 4       2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
#                               ...
# 1795    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1796    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1797    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1798    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# 1799    2024 (COMPLETE)\QUADRAT\IMAGE AND CPCE FILE\SH...
# Name: filepath, Length: 1698, dtype: object
# Annotations File: D:/CROPPED-CORALS/index.csv
# Image Base Directory: D:/CROPPED-CORALS/
# Train=False, Transform=ToTensor(), Target Transform=None, Random State=42

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay = 0.001, momentum = 0.9)  

# Train the model
import gc
total_step = len(train_loader)

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        print(f"Epoch {epoch + 1}/{num_epochs} | Batch {i}")

        #Move tensors to the configured device
        images = images.float()
        images = images.to(device)
        labels = labels.long()
        labels = labels.to(device)

        #Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        #Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        del images, labels, outputs
        torch.cuda.empty_cache()
        gc.collect()

    print ('Epoch [{}/{}], Loss: {:.4f}' 
                .format(epoch+1, num_epochs, loss.item()))

#Validation
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in valid_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        del images, labels, outputs

    print('Accuracy of the network on the {} validation images: {} %'.format(len(valid_loader.dataset), 100 * correct / total))
# Out:
# Epoch 1/20 | Batch 0
# torch.Size([4, 3, 500, 500])
# torch.Size([4, 64, 250, 250])
# torch.Size([4, 64, 250, 250])
# torch.Size([4, 64, 250, 250])
# torch.Size([4, 64, 124, 124])
# torch.Size([4, 256, 124, 124])
# torch.Size([4, 256, 124, 124])
# torch.Size([4, 256, 124, 124])
# torch.Size([4, 512, 62, 62])
# torch.Size([4, 512, 62, 62])
# torch.Size([4, 512, 62, 62])
# torch.Size([4, 512, 62, 62])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 2048, 16, 16])
# torch.Size([4, 2048, 16, 16])
# torch.Size([4, 2048, 16, 16])
# torch.Size([4, 2048, 1, 1])
# torch.Size([4, 2048])
# Epoch 1/20 | Batch 1
# torch.Size([4, 3, 500, 500])
# torch.Size([4, 64, 250, 250])
# torch.Size([4, 64, 250, 250])
# torch.Size([4, 64, 250, 250])
# torch.Size([4, 64, 124, 124])
# torch.Size([4, 256, 124, 124])
# torch.Size([4, 256, 124, 124])
# torch.Size([4, 256, 124, 124])
# torch.Size([4, 512, 62, 62])
# torch.Size([4, 512, 62, 62])
# torch.Size([4, 512, 62, 62])
# torch.Size([4, 512, 62, 62])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 2048, 16, 16])
# torch.Size([4, 2048, 16, 16])
# torch.Size([4, 2048, 16, 16])
# torch.Size([4, 2048, 1, 1])
# torch.Size([4, 2048])
# Epoch 1/20 | Batch 2
# torch.Size([4, 3, 500, 500])
# torch.Size([4, 64, 250, 250])
# torch.Size([4, 64, 250, 250])
# torch.Size([4, 64, 250, 250])
# torch.Size([4, 64, 124, 124])
# torch.Size([4, 256, 124, 124])
# torch.Size([4, 256, 124, 124])
# torch.Size([4, 256, 124, 124])
# torch.Size([4, 512, 62, 62])
# torch.Size([4, 512, 62, 62])
# torch.Size([4, 512, 62, 62])
# torch.Size([4, 512, 62, 62])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# torch.Size([4, 1024, 31, 31])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 20
#      17 labels = labels.to(device)
#      19 #Forward pass
# ---> 20 outputs = model(images)
#      21 loss = criterion(outputs, labels)
#      23 #Backward and optimize
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Justin\Desktop\Projects\DLSU\thesis\corallian-classifier\model\resnet_hdc.py:242, in ResNet101_HDC.forward(self, x)
#     240 for layer in self.layers:
#     241     self._print(x.size())
# --> 242     x = layer(x)
#     244 self._print(x.size())
#     245 x = x.view(x.size(0), -1)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Justin\Desktop\Projects\DLSU\thesis\corallian-classifier\model\resnet_hdc.py:94, in ResidualHDCBlock_X.forward(self, x)
#      90 conv = self.conv_1x1_increase(conv)
#      92 out = conv + residual
# ---> 94 return self.relu(out)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\activation.py:133, in ReLU.forward(self, input)
#     132 def forward(self, input: Tensor) -> Tensor:
# --> 133     return F.relu(input, inplace=self.inplace)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\functional.py:1704, in relu(input, inplace)
#    1702     result = torch.relu_(input)
#    1703 else:
# -> 1704     result = torch.relu(input)
#    1705 return result
#
# KeyboardInterrupt:
